# %% [markdown]
# # First test of blogging with a notebook using Nikola
#
# From what I see, it seems to work rather nicely once one get's around the initial setup problems.
# Let's see if latex works:
# $$ f = sin(t) $$
#
# And how does a quote look in here:
#
#     Like this, folks.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
t = linspace(0, 2*pi, 100)

# %%
plot(t, sin(t))
